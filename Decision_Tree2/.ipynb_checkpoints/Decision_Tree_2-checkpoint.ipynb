# %%
import pandas as pd
import os
import joblib as jb
import sklearn
import pydotplus

# %%
from sklearn.preprocessing import LabelEncoder

# %%
pd.read_excel('Combined_Updated.xlsx')
# Out:
#        AgeCategory  Workclass  Education  EducationNum  MaritalStatus  \
# 0                3          6          9            12              4
# 1                0          5          9            12              2
# 2                3          3         11             8              0
# 3                0          3          1             6              2
# 4                3          3          9            12              2
# ...            ...        ...        ...           ...            ...
# 48837            3          3          9            12              0
# 48838            2          3         11             8              6
# 48839            3          3          9            12              2
# 48840            0          3          9            12              0
# 48841            3          4          9            12              2
#
#        Occupation  Relationship  Sex  NativeCountry  Race  FnlwgtCategory  \
# 0               0             1    1             38     4               3
# 1               3             0    1             38     4               3
# 2               5             1    1             38     4               0
# 3               5             0    1             38     2               0
# 4               9             5    0              4     2               0
# ...           ...           ...  ...            ...   ...             ...
# 48837           9             1    0             38     4               0
# 48838           9             2    1             38     2               0
# 48839           9             0    1             38     4               0
# 48840           0             3    1             38     1               3
# 48841           3             0    1             38     4               0
#
#        CapitalGainCategory  CapitalLossCategory  HoursPerWeekCategory  Class
# 0                        0                    1                     2      0
# 1                        2                    1                     2      0
# 2                        2                    1                     2      0
# 3                        2                    1                     2      0
# 4                        2                    1                     2      0
# ...                    ...                  ...                   ...    ...
# 48837                    2                    1                     2      0
# 48838                    2                    1                     2      0
# 48839                    2                    1                     0      0
# 48840                    0                    1                     2      0
# 48841                    2                    1                     0      1
#
# [48842 rows x 15 columns]

# %%
data=pd.read_excel('Combined_Updated.xlsx')

# %%
xc=['AgeCategory','Workclass','Education','EducationNum','MaritalStatus','Occupation','Relationship','NativeCountry','Sex','Race','FnlwgtCategory','CapitalGainCategory','CapitalLossCategory','HoursPerWeekCategory']
y=['Yes','No']
all_input=data[xc]
all_class=data['Class']

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
(x_train,x_test,y_train,y_test)=train_test_split(all_input,all_class,train_size=0.67,random_state=10)

# %%
clf = DecisionTreeClassifier(random_state=10)
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=10)

# %%
y_train_pred=clf.predict(x_train)

y_test_pred=clf.predict(x_test)

# %%
print(y_train_pred)
y_train
# Out:
# [0 1 0 ... 0 0 0]
# 39203    0
# 16702    1
# 43825    0
# 48735    1
# 34480    0
#         ..
# 40059    1
# 28017    0
# 29199    0
# 40061    0
# 17673    0
# Name: Class, Length: 32724, dtype: int64

# %%
from sklearn import metrics,model_selection,preprocessing
wrong_train_pred=(y_train !=y_train_pred).sum()
print("Total wrong detected on training data= {}".format(wrong_train_pred))

accuracy_train=metrics.accuracy_score(y_train,y_train_pred)
print("Accuracy of this model on training data= {:.3f}".format(accuracy_train))
# Out:
# Total wrong detected on training data= 2812
# Accuracy of this model on training data= 0.914

# %%
wrong_test_pred=(y_test !=y_test_pred).sum()
print("Total wrong detected on test data = {}".format(wrong_test_pred))

accuracy_test=metrics.accuracy_score(y_test,y_test_pred)
print("Accuracy of this model on test data = {:.3f}".format(accuracy_test))
# Out:
# Total wrong detected on test data = 3058
# Accuracy of this model on test data = 0.810

# %%
train_accuracy=[]
test_accuracy=[]
train_error=[]
valid_error=[]
test_error=[]
for depth in range(1,40):
    dt_model_tree=DecisionTreeClassifier(max_depth=depth,random_state=10)
    dt_model_tree.fit(x_train,y_train)
    train_accuracy.append(dt_model_tree.score(x_train,y_train))
    test_accuracy.append(dt_model_tree.score(x_test,y_test))

# %%
frame = pd.DataFrame({'max_depth': range(1,40),'train_acc':train_accuracy,'test_acc':test_accuracy})
frame.head()
# Out:
#    max_depth  train_acc  test_acc
# 0          1   0.761062  0.760020
# 1          2   0.814876  0.812446
# 2          3   0.821691  0.819705
# 3          4   0.831653  0.828577
# 4          5   0.832508  0.829445

# %%
import numpy as np

train_accuracy = np.array(train_accuracy)  
train_error = (1 - train_accuracy) * 32562

test_accuracy = np.array(test_accuracy)  
test_error = (1 - test_accuracy) * 8140

# %%
from IPython.display import Image,display
import matplotlib.pyplot as plt,pydotplus
import graphviz

# %%
import matplotlib.pyplot as plt,pydotplus
plt.figure(figsize=(12,6))
plt.plot(frame['max_depth'],frame['train_acc'],label='Training',marker='o')
plt.plot(frame['max_depth'],frame['test_acc'],label='Test',marker='v')
plt.xlabel('Depth of tree')
plt.ylabel('Perfromance accuracy')
plt.legend()

# %%
frame1 = pd.DataFrame({'max_depth': range(1,40),'train_err':train_error,'test_err':test_error})

# %%
import matplotlib.pyplot as plt,pydotplus
plt.figure(figsize=(12,6))
plt.plot(frame1['max_depth'],frame1['train_err'],label='Training',marker='o')
plt.plot(frame1['max_depth'],frame1['test_err'],label='Test',marker='v')
plt.xlabel('log(Vertices)(as a fuction of depth of tree i.e. vertices = 2^(n+1) - 1)')
plt.ylabel('Number of Error')
plt.legend()

# %%
from sklearn import tree
plt.figure(figsize=(200, 20)) 
tree.plot_tree(clf, filled=True,max_depth=4, feature_names=['HoursPerWeekCategory','CapitalLossCategory','CapitalGainCategory','HoursPerWeekCategory','Race','NativeCountry','Sex','Relationship','Occupation','MaritalStatus','EducationNum','Education','Workclass','AgeCategory'],class_names=['Yes','No'],fontsize=12)
# Out:
# [Text(0.5, 0.9166666666666666, 'Sex <= 0.5\ngini = 0.364\nsamples = 32724\nvalue = [24905, 7819]\nclass = Yes'),
#  Text(0.25, 0.75, 'HoursPerWeekCategory <= 11.5\ngini = 0.495\nsamples = 13090\nvalue = [7181, 5909]\nclass = Yes'),
#  Text(0.125, 0.5833333333333334, 'HoursPerWeekCategory <= 7.5\ngini = 0.445\nsamples = 9163\nvalue = [6098, 3065]\nclass = Yes'),
#  Text(0.0625, 0.4166666666666667, 'Education <= 1.5\ngini = 0.215\nsamples = 1542\nvalue = [1353, 189]\nclass = Yes'),
#  Text(0.03125, 0.25, 'HoursPerWeekCategory <= 5.5\ngini = 0.476\nsamples = 110\nvalue = [67, 43]\nclass = Yes'),
#  Text(0.015625, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.046875, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.09375, 0.25, 'AgeCategory <= 1.5\ngini = 0.183\nsamples = 1432\nvalue = [1286, 146]\nclass = Yes'),
#  Text(0.078125, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.109375, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.1875, 0.4166666666666667, 'Education <= 1.5\ngini = 0.47\nsamples = 7621\nvalue = [4745, 2876]\nclass = Yes'),
#  Text(0.15625, 0.25, 'HoursPerWeekCategory <= 0.5\ngini = 0.451\nsamples = 777\nvalue = [267, 510]\nclass = No'),
#  Text(0.140625, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.171875, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.21875, 0.25, 'HoursPerWeekCategory <= 0.5\ngini = 0.452\nsamples = 6844\nvalue = [4478, 2366]\nclass = Yes'),
#  Text(0.203125, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.234375, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.375, 0.5833333333333334, 'Education <= 1.5\ngini = 0.399\nsamples = 3927\nvalue = [1083, 2844]\nclass = No'),
#  Text(0.3125, 0.4166666666666667, 'HoursPerWeekCategory <= 1.0\ngini = 0.161\nsamples = 693\nvalue = [61, 632]\nclass = No'),
#  Text(0.28125, 0.25, 'Education <= 0.5\ngini = 0.105\nsamples = 377\nvalue = [21, 356]\nclass = No'),
#  Text(0.265625, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.296875, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.34375, 0.25, 'AgeCategory <= 0.5\ngini = 0.221\nsamples = 316\nvalue = [40, 276]\nclass = No'),
#  Text(0.328125, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.359375, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.4375, 0.4166666666666667, 'Workclass <= 0.5\ngini = 0.432\nsamples = 3234\nvalue = [1022, 2212]\nclass = No'),
#  Text(0.40625, 0.25, 'AgeCategory <= 1.5\ngini = 0.178\nsamples = 396\nvalue = [39, 357]\nclass = No'),
#  Text(0.390625, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.421875, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.46875, 0.25, 'HoursPerWeekCategory <= 1.0\ngini = 0.453\nsamples = 2838\nvalue = [983, 1855]\nclass = No'),
#  Text(0.453125, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.484375, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.75, 0.75, 'Sex <= 4.5\ngini = 0.176\nsamples = 19634\nvalue = [17724, 1910]\nclass = Yes'),
#  Text(0.625, 0.5833333333333334, 'Education <= 1.5\ngini = 0.123\nsamples = 18097\nvalue = [16902, 1195]\nclass = Yes'),
#  Text(0.5625, 0.4166666666666667, 'HoursPerWeekCategory <= 11.5\ngini = 0.479\nsamples = 847\nvalue = [510, 337]\nclass = Yes'),
#  Text(0.53125, 0.25, 'AgeCategory <= 0.5\ngini = 0.379\nsamples = 520\nvalue = [388, 132]\nclass = Yes'),
#  Text(0.515625, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.546875, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.59375, 0.25, 'HoursPerWeekCategory <= 1.0\ngini = 0.468\nsamples = 327\nvalue = [122, 205]\nclass = No'),
#  Text(0.578125, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.609375, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.6875, 0.4166666666666667, 'HoursPerWeekCategory <= 12.5\ngini = 0.095\nsamples = 17250\nvalue = [16392, 858]\nclass = Yes'),
#  Text(0.65625, 0.25, 'HoursPerWeekCategory <= 11.5\ngini = 0.072\nsamples = 16326\nvalue = [15716, 610]\nclass = Yes'),
#  Text(0.640625, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.671875, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.71875, 0.25, 'AgeCategory <= 0.5\ngini = 0.393\nsamples = 924\nvalue = [676, 248]\nclass = Yes'),
#  Text(0.703125, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.734375, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.875, 0.5833333333333334, 'HoursPerWeekCategory <= 9.5\ngini = 0.498\nsamples = 1537\nvalue = [822, 715]\nclass = Yes'),
#  Text(0.8125, 0.4166666666666667, 'NativeCountry <= 3.5\ngini = 0.435\nsamples = 914\nvalue = [622, 292]\nclass = Yes'),
#  Text(0.78125, 0.25, 'Education <= 1.5\ngini = 0.497\nsamples = 384\nvalue = [206, 178]\nclass = Yes'),
#  Text(0.765625, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.796875, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.84375, 0.25, 'NativeCountry <= 8.5\ngini = 0.338\nsamples = 530\nvalue = [416, 114]\nclass = Yes'),
#  Text(0.828125, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.859375, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.9375, 0.4166666666666667, 'HoursPerWeekCategory <= 12.5\ngini = 0.436\nsamples = 623\nvalue = [200, 423]\nclass = No'),
#  Text(0.90625, 0.25, 'Education <= 1.5\ngini = 0.473\nsamples = 454\nvalue = [174, 280]\nclass = No'),
#  Text(0.890625, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.921875, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.96875, 0.25, 'NativeCountry <= 11.5\ngini = 0.26\nsamples = 169\nvalue = [26, 143]\nclass = No'),
#  Text(0.953125, 0.08333333333333333, '\n  (...)  \n'),
#  Text(0.984375, 0.08333333333333333, '\n  (...)  \n')]
